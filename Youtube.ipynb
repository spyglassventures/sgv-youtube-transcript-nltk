# %%
# pip install youtube-transcript-api
import numpy as np
import pandas as pd

# %%
from youtube_transcript_api import YouTubeTranscriptApi
#video_id = 'AzdxbzHtjgs'
video_id = 'l4RHzrdWr7k' # Philipps Video
text = YouTubeTranscriptApi.get_transcript(video_id)

# %%
type(text)
# Out:
# list

# %%
text
# Out:
# [{'text': '[Musik]', 'start': 3.09, 'duration': 3.089},
#  {'text': 'ich bin philipp haas und ich bin', 'start': 6.92, 'duration': 5.11},
#  {'text': 'leidenschaftlicher aktieninvestor und',
#   'start': 9.36,
#   'duration': 4.949},
#  {'text': 'auch betreiber des youtube kanals und',
#   'start': 12.03,
#   'duration': 4.259},
#  {'text': 'blogs investor satzpunkt net ich habe',
#   'start': 14.309,
#   'duration': 3.991},
#  {'text': 'davor ein master an der universität st',
#   'start': 16.289,
#   'duration': 3.631},
#  {'text': 'gallen in paris gemacht', 'start': 18.3, 'duration': 3.93},
#  {'text': 'fondsmanager und habe auch sonst ein',
#   'start': 19.92,
#   'duration': 4.23},
#  {'text': 'bisschen auch auf den bestens weiter',
#   'start': 22.23,
#   'duration': 3.779},
#  {'text': 'gearbeitet wo ich zum beispiel bei',
#   'start': 24.15,
#   'duration': 3.869},
#  {'text': 'harvey keppel auch bei finanztreff.de',
#   'start': 26.009,
#   'duration': 4.83},
# ...

# %%
import json

# %%
text_json = json.dumps(text)

# %%
text_json
# Out:
# '[{"text": "[Musik]", "start": 3.09, "duration": 3.089}, {"text": "ich bin philipp haas und ich bin", "start": 6.92, "duration": 5.11}, {"text": "leidenschaftlicher aktieninvestor und", "start": 9.36, "duration": 4.949}, {"text": "auch betreiber des youtube kanals und", "start": 12.03, "duration": 4.259}, {"text": "blogs investor satzpunkt net ich habe", "start": 14.309, "duration": 3.991}, {"text": "davor ein master an der universit\\u00e4t st", "start": 16.289, "duration": 3.631}, {"text": "gallen in paris gemacht", "start": 18.3, "duration": 3.93}, {"text": "fondsmanager und habe auch sonst ein", "start": 19.92, "duration": 4.23}, {"text": "bisschen auch auf den bestens weiter", "start": 22.23, "duration": 3.779}, {"text": "gearbeitet wo ich zum beispiel bei", "start": 24.15, "duration": 3.869}, {"text": "harvey keppel auch bei finanztreff.de", "start": 26.009, "duration": 4.83}, {"text": "von anfang an mit involviert war und mir", "start": 28.019, "duration": 4.141}, {"text": "is
# ...

# %%
text_df = pd.read_json(text_json)

# %%
text_df[['text']].head(35)
# Out:
#                                         text
# 0                                    [Musik]
# 1           ich bin philipp haas und ich bin
# 2      leidenschaftlicher aktieninvestor und
# 3      auch betreiber des youtube kanals und
# 4      blogs investor satzpunkt net ich habe
# 5     davor ein master an der universität st
# 6                    gallen in paris gemacht
# 7       fondsmanager und habe auch sonst ein
# 8       bisschen auch auf den bestens weiter
# 9         gearbeitet wo ich zum beispiel bei
# 10     harvey keppel auch bei finanztreff.de
# 11  von anfang an mit involviert war und mir
# 12  ist auch dieses kann dadurch auch dieser
# 13         zum thema finanzielle bildung und
# 14  fairere finanzprodukte sehr sehr wichtig
# 15      zum investieren oder zur aktie nicht
# 16       gekommen eigentlich damals über den
# 17      neuen markt aber ich glaube ich eine
# 18   sechste klasse und habe ein paar bücher
# 19      gelesen und ich glaube kostolany war
# ...

# %%
investresearch1 = text_df[['text']].to_string(index=False).replace("\n", "")
#text_df[['text']].to_string(index=False)

# %%
len(investresearch1)
# Out:
# 10604

# %%
#sorted(set(investresearch1))
#len(set(investresearch1))

def lexical_diversity(text):
    return len(text) / len(set(text))

# %%
import nltk
import nltk.corpus
from nltk.corpus import brown
from nltk.tokenize import sent_tokenize
nltk.download('punkt') # this can take a while
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(investresearch1)
#print(tokenized_word)

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 583 samples and 1565 outcomes>

# %%
fdist.most_common(5)
# Out:
# [('und', 56), ('ich', 46), ('die', 43), ('auch', 41), ('dann', 34)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show();

# %%
# Stopwords
nltk.download('stopwords')
from nltk.corpus import stopwords
#stop_words=set(stopwords.words("english"))
stop_words=set(stopwords.words("german"))
print(stop_words)
# Out:
# {'einem', 'jedem', 'deinen', 'dieser', 'daß', 'meines', 'dir', 'einen', 'da', 'jeden', 'keines', 'ihr', 'unseren', 'etwas', 'meiner', 'allen', 'seines', 'machen', 'aber', 'diesem', 'vom', 'wir', 'derselben', 'jeder', 'keinen', 'für', 'dem', 'gewesen', 'hatte', 'hatten', 'meinem', 'weg', 'werden', 'anderes', 'während', 'wollen', 'diese', 'manches', 'alle', 'manchen', 'anders', 'seinen', 'gegen', 'euch', 'wieder', 'derselbe', 'denselben', 'weil', 'wirst', 'bis', 'ins', 'uns', 'welche', 'mein', 'ihm', 'damit', 'auch', 'eine', 'dann', 'oder', 'nichts', 'einigem', 'nicht', 'andern', 'musste', 'einmal', 'von', 'deines', 'dein', 'einer', 'sonst', 'zum', 'dieselben', 'alles', 'dazu', 'doch', 'mir', 'manche', 'andere', 'man', 'demselben', 'mancher', 'wo', 'anderr', 'zur', 'will', 'also', 'eurem', 'kann', 'welcher', 'waren', 'ein', 'jenem', 'was', 'bin', 'mich', 'ihnen', 'zwischen', 'den', 'deine', 'zwar', 'soll', 'derer', 'würde', 'um', 'dasselbe', 'unser', 'wollte', 'jene', 'euer', 'jedes', 
# ...

# %%
filtered_sent=[]
for w in tokenized_word:
    if w not in stop_words:
        filtered_sent.append(w)
#print("Tokenized Sentence:",tokenized_word)
#print("Filterd Sentence:",filtered_word)

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("*********************")
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['text', '[', 'Musik', ']', 'philipp', 'haas', 'leidenschaftlicher', 'aktieninvestor', 'betreiber', 'youtube', 'kanals', 'blogs', 'investor', 'satzpunkt', 'net', 'davor', 'master', 'universität', 'st', 'gallen', 'paris', 'gemacht', 'fondsmanager', 'bisschen', 'bestens', 'gearbeitet', 'beispiel', 'harvey', 'keppel', 'finanztreff.devon', 'anfang', 'involviert', 'mirist', 'dadurch', 'thema', 'finanzielle', 'bildung', 'undfairere', 'finanzprodukte', 'wichtig', 'investieren', 'aktie', 'gekommen', 'eigentlich', 'damals', 'neuen', 'markt', 'glaube', 'sechste', 'klasse', 'paar', 'bücher', 'gelesen', 'glaube', 'kostolany', 'daran', 'erinnern', 'damals', 'schüler', 'warnicht', 'aktien', 'unterhalten', 'daweiß', 'einfach', 'blase', 'geld', 'gewonnen', 'mann', 'einfach', 'aktien', 'gezeichnet', 'verdoppelt', 'tag', 'verkauft', 'konnte', 'einfach', 'geld', 'einstreichen', 'geschichte', 'oft', 'aktien', 'raus', 'geholt', 'vater', 'gekauft', 'konnte', 'gewinne', 'bruder', 'bissch
# ...

# %%
#Lexicon Normalization
#performing stemming and Lemmatization
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "flying"
#print("Lemmatized Word:",lem.lemmatize(word,"v"))
#print("Stemmed Word:",stem.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# pip install lexical-diversity
nltk.download('gutenberg')
nltk.download('genesis')
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('webtext')
nltk.download('treebank')
from nltk.book import *
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\Praxis\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
# lexical diversity
def lexical_diversity(text):
    return len(set(text)) / len(text)

# percentage
def percentage(count, total):
    return 100 * count / total

# %%
#type(text1)
Comp1 = nltk.Text(investresearch1)
type(Comp1)
# Out:
# nltk.text.Text

# %%
import pandas as pd

# print the lexical diversity of all the texts.
texts = [text1, text2, text3, text4, text5,
        text6, text7, text8, text9, Comp1]

lexicalDiversity = [lexical_diversity(text) for text in texts]
tokens = [len(text) for text in texts]
types = [len(set(text)) for text in texts]
title = [text.name for text in texts]

ld = pd.DataFrame({'title': title, 'tokens': tokens, 'types': types,
                   'lexical_diversity': lexicalDiversity})

ld.sort_values(by='lexical_diversity', ascending=False)
# Out:
#                                                title  tokens  types  \
# 7                                   Personals Corpus    4867   1108
# 4                                        Chat Corpus   45010   6066
# 5                    Monty Python and the Holy Grail   16967   2166
# 6                                Wall Street Journal  100676  12408
# 8  The Man Who Was Thursday by G . K . Chesterton...   69213   6807
# 0                  Moby Dick by Herman Melville 1851  260819  19317
# 3                           Inaugural Address Corpus  149797   9913
# 2                                The Book of Genesis   44764   2789
# 1          Sense and Sensibility by Jane Austen 1811  141576   6833
# 9                                 t e x t        ...   10604     46
#
#    lexical_diversity
# 7           0.227656
# 4           0.134770
# 5           0.127660
# 6           0.123247
# 8           0.098349
# 0           0.074063
# 3           0.066176
# 2           0.062305
# ...
